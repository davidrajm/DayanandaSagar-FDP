# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
df = pd.read_csv('diabetes.csv')
outcome_one_hot = pd.get_dummies(df['Outcome'])
del df['Outcome']
df = pd.concat([df,outcome_one_hot],axis=1)
df.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  0  1
# 0                     0.627   50  0  1
# 1                     0.351   31  1  0

# %%
# prepare it as numpy array
X = df.values[:,:8]
y = df.values[:,8:]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
model = Sequential()
model.add(Dense(2,input_shape=(8,)))
model.add(Activation('sigmoid'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy']
             )

# %%
model.fit(X_train,y_train, epochs=50,batch_size=1)
# Out:
# Epoch 1/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.7538 - accuracy: 0.6205
# Epoch 2/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6844 - accuracy: 0.6156
# Epoch 3/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.7175 - accuracy: 0.6384
# Epoch 4/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.7385 - accuracy: 0.6221
# Epoch 5/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.7016 - accuracy: 0.6238
# Epoch 6/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.7333 - accuracy: 0.6336
# Epoch 7/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6933 - accuracy: 0.6466
# Epoch 8/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.7334 - accuracy: 0.6336
# Epoch 9/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.7304 - accuracy: 0.6417
# Epoch 10/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.7017 - accuracy: 0.6629
# Epoch 11/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6985 - accuracy: 0.6221
# Epoch 12/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6850 - accuracy: 0.6433
# Epoch 13/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.7202 - accuracy: 0.6417
# Epoch 14/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.7059 - accuracy: 0.6336
# Epoch 15/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6852 - accuracy: 0.6466
# Epoch 16/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.7019 - accuracy: 0.6287
# Epoch 17/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6733 - accuracy: 0.6726
# Epoch 18/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6526 - accuracy: 0.6612
# Epoch 19/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.7056 - accuracy: 0.6450
# Epoch 20/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6750 - accuracy: 0.6564
# Epoch 21/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.6661
# Epoch 22/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6782 - accuracy: 0.6531
# Epoch 23/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6825 - accuracy: 0.6433
# Epoch 24/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6715 - accuracy: 0.6612
# Epoch 25/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6925 - accuracy: 0.6531
# Epoch 26/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6845 - accuracy: 0.6450
# Epoch 27/50
# 614/614 [==============================] - 2s 2ms/step - loss: 0.6571 - accuracy: 0.6564
# Epoch 28/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6945 - accuracy: 0.6678
# Epoch 29/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6644 - accuracy: 0.6775
# Epoch 30/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6402 - accuracy: 0.6661
# Epoch 31/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6715 - accuracy: 0.6808
# Epoch 32/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6544 - accuracy: 0.6694
# Epoch 33/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6767 - accuracy: 0.6612
# Epoch 34/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6244 - accuracy: 0.6889
# Epoch 35/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6523 - accuracy: 0.6629
# Epoch 36/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6517 - accuracy: 0.6726
# Epoch 37/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6513 - accuracy: 0.6922
# Epoch 38/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6506 - accuracy: 0.6808
# Epoch 39/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6199 - accuracy: 0.6694
# Epoch 40/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6442 - accuracy: 0.6840
# Epoch 41/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6401 - accuracy: 0.6889
# Epoch 42/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6325 - accuracy: 0.6694
# Epoch 43/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6458 - accuracy: 0.6971
# Epoch 44/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6402 - accuracy: 0.7020
# Epoch 45/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6629 - accuracy: 0.6971
# Epoch 46/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6898 - accuracy: 0.6547
# Epoch 47/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6516 - accuracy: 0.6726
# Epoch 48/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6354 - accuracy: 0.6759
# Epoch 49/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6356 - accuracy: 0.7003
# Epoch 50/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6411 - accuracy: 0.6922

# %%
loss, accuracy = model.evaluate(X_test,y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4507 - accuracy: 0.8182

# %%
loss
# Out:
# 0.4506857693195343

# %%
accuracy
# Out:
# 0.8181818127632141
